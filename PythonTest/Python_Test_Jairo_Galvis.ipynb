# %% [markdown]
# ## Research Assistant Test
# ### DECTI Unit - World Bank
# **Jairo Enrique Galvis Avella**
#
# August - 2024

# %% [markdown]
# ### Context
#
# The ForeignNames_2019_2020.csv and ForeignNames_2021.csv are datasets of commercial foreign firm names and their location countries. ForeignNames_2019_2020.csv contains firm names from 2019-2020. ForeignNames_2021.csv contains firm names from 2021.
# Data entry has been conducted manually by multiple people with no quality control, and as a result, the same company may have been recorded under different names, for instance: “Teaboard Ltd.” and “Teaboard Limited”.

# %%
#Python version 3.11.5

# To run this notebook you need to install the follwoing packages:
# pip install pandas
# pip install fuzzywuzzy
# pip install tqdm
# pip install scikit-learn
# pip install ipython

# %% [markdown]
# ### Part 1
#
# Use ForeignNames_2019_2020.csv for the following tasks:

# %% [markdown]
# + Clean the firm names and assign a unique identifier (ID) to each firm (include it in a new variable “cleaned_ID”).  Give a corresponding unique cleaned name to all the names (include it in a new variable called “cleaned_name”). For example, if Teaboard Limited, Teaboard LTd, Teaboar Ld all get assigned the same name, choose the best name to give to this group, lets say “Teaboard Limited”.
#
# + Please do this cleaning of firm names country by country (countries are identified by the ISO3 codes included in the file ForeignNames_2019_2020.csv and their mapping to country names is given in the separate file Country_Name_ISO3.csv we also sent you) as stopwords (words you discount in matching) may vary from country to country and also because it minimizes error.
#
# + For all firm ID assignments, please follow a convention such that the country iso3 is attached in front of the numeric ID to identify the country of the firm.

# %%
import os
import pandas as pd
from fuzzywuzzy import fuzz
from tqdm import tqdm
from IPython.display import display

# Set the working directory
os.chdir('/Users/jairogalvis/Downloads/PythonRStataTest2024/PythonTest/')

# Load the datasets
foreign_names = pd.read_csv('ForeignNames_2019_2020.csv')
country_mapping = pd.read_csv('Country_Name_ISO3.csv')

# Display the initial number of rows of 'Country_Name_ISO3.csv' dataset
print(f"Initial number of rows: {country_mapping.shape[0]}")

# Remove rows where 'country_name' is empty or NaN in 'Country_Name_ISO3.csv' dataset
country_mapping_cleaned = country_mapping[country_mapping['country_name'].notna() & (country_mapping['country_name'].str.strip() != '')]

# Display the number of rows after cleaning of 'Country_Name_ISO3.csv' dataset
print(f"Number of rows after cleaning: {country_mapping_cleaned.shape[0]}")

# Ensure consistent formatting in the country_iso3 column
foreign_names['country_name'] = foreign_names['foreigncountry_cleaned'].str.strip()
country_mapping['country_name'] = country_mapping['country_name'].str.strip()

# Merge the sample with country mapping to include country names
foreign_names = foreign_names.merge(country_mapping, on='country_name', how='left')

# Function to clean firm names
def clean_name(name):
    if isinstance(name, str):  # Ensure the value is a string
        name = name.lower()
        name = name.replace('.', '')  # Remove periods
        name = ' '.join(name.split())  # Remove extra spaces
        return name.title()
    else:
        return ''  # Handle non-string values by returning an empty string

# Function to match and assign cleaned name, unique ID, and matching score
def assign_cleaned_name_id(df):
    cleaned_names = {}
    unique_id = 1
    
    # Function to find the best fuzzy match from a list of cleaned names
    def match_name(name, list_names, min_score=80):
        max_score = -1  # Initial score
        max_name = ""   # Initial best match
        for name2 in list_names:
            score = fuzz.ratio(name, name2)
            if score > min_score and score > max_score:
                max_name = name2
                max_score = score
        return max_name, max_score
    
    cleaned_name_list = []
    cleaned_id_list = []
    matching_score_list = []
    
    for index, row in tqdm(df.iterrows(), total=df.shape[0], desc=f"Cleaning and Matching Firms for {df['country_name'].iloc[0]}"):
        original_name = row['foreign']
        cleaned_name = clean_name(original_name)
        
        # Find the best match for the cleaned name
        best_match, best_score = match_name(cleaned_name, list(cleaned_names.keys()), min_score=80)
        
        if best_match:
            # Use the matched name as the cleaned name
            cleaned_name_list.append(best_match)
            cleaned_id_list.append(f"{cleaned_names[best_match]}_{df['country_iso3'].iloc[0]}")
            matching_score_list.append(best_score)
        else:
            # Use the current cleaned name and assign a new ID
            cleaned_names[cleaned_name] = unique_id
            cleaned_name_list.append(cleaned_name)
            cleaned_id_list.append(f"{unique_id}_{df['country_iso3'].iloc[0]}") 
            matching_score_list.append(0)  # No match found, so score is 0
            unique_id += 1
    
    # Use .loc[] to set the values
    df.loc[:, 'cleaned_name'] = cleaned_name_list
    df.loc[:, 'cleaned_ID'] = cleaned_id_list
    df.loc[:, 'matching_score'] = matching_score_list
    
    return df

# Group by country and apply the cleaning and matching function
cleaned_df_list = []
for country, group in tqdm(foreign_names.groupby('country_iso3'), desc="Processing by Country"):
    cleaned_group = assign_cleaned_name_id(group)
    cleaned_df_list.append(cleaned_group)

# Concatenate all the cleaned groups into one DataFrame
cleaned_df = pd.concat(cleaned_df_list, ignore_index=True)

# Select the specified columns
final_columns = ['foreign', 'foreigncountry_cleaned', 'country_iso3', 'shpmtyear', 'cleaned_name', 'cleaned_ID', 'matching_score']
cleaned_df = cleaned_df[final_columns]

# Save the cleaned dataset
cleaned_df.to_csv('Cleaned_ForeignNames_2019_2020.csv', index=False)

# Display a sample of the DataFrame
display(cleaned_df.head(20))
# Out:
# Initial number of rows: 285
# Number of rows after cleaning: 284
# Cleaning and Matching Firms for Aruba: 100%|██████████| 27/27 [00:00<00:00, 9171.22it/s]
# Cleaning and Matching Firms for Afghanistan: 100%|██████████| 210/210 [00:00<00:00, 13932.14it/s]
# Cleaning and Matching Firms for Angola: 100%|██████████| 223/223 [00:00<00:00, 12576.03it/s]
# Cleaning and Matching Firms for Anguilla: 100%|██████████| 31/31 [00:00<00:00, 26742.79it/s]
# Cleaning and Matching Firms for Albania: 100%|██████████| 99/99 [00:00<00:00, 22122.33it/s]
# Cleaning and Matching Firms for Andorra: 100%|██████████| 4/4 [00:00<00:00, 7466.50it/s]
# Cleaning and Matching Firms for Netherlands Antilles: 100%|██████████| 135/135 [00:00<00:00, 15048.53it/s]
# Cleaning and Matching Firms for United Arab Emirates: 100%|██████████| 7510/7510 [00:11<00:00, 640.80it/s]
# Cleaning and Matching Firms for Argentina: 100%|██████████| 1227/1227 [00:00<00:00, 3368.43it/s]
# Cleaning and Matching Firms for Armenia: 100%|██████████| 85/85 [00:00<00:00, 24631.47it/s]
# Cleaning and Matching Firms for American Samoa: 100%|██████████| 166/166 [00:00<00:00, 18043.76it/s]
# Cleaning and Matching Firms for Australia: 100%|██████████| 16184/16184 [01:01<00:00, 263.79it/s]
# Cleaning and Matching Firms for Austria: 100%|██████████| 1763/1763 [00:00<00:00, 2232.62it/s]
# Cleaning and Matching Firms for Azerbaijan: 100%|██████████| 107/107 [00:00<00:00, 20858.46it/s]
# Cleaning and Matching Firms for Burundi: 100%|██████████| 25/25 [00:00<00:00, 24044.39it/s]
# Cleaning and Matching Firms for Belgium: 100%|██████████| 3792/3792 [00:03<00:00, 1062.54it/s]
# Cleaning and Matching Firms for Benin: 100%|██████████| 89/89 [00:00<00:00, 22262.23it/s]
# Cleaning and Matching Firms for Burkina Faso: 100%|██████████| 101/101 [00:00<00:00, 18611.05it/s]
# Cleaning and Matching Firms for Bangladesh: 100%|██████████| 3738/3738 [00:03<00:00, 1187.29it/s]
# Cleaning and Matching Firms for Bulgaria: 100%|██████████| 581/581 [00:00<00:00, 6446.37it/s]
# Cleaning and Matching Firms for Bahrain: 100%|██████████| 565/565 [00:00<00:00, 6253.38it/s]
# Cleaning and Matching Firms for Bahamas: 100%|██████████| 47/47 [00:00<00:00, 24777.81it/s]
# Cleaning and Matching Firms for Bosnia and Herzegovina: 100%|██████████| 58/58 [00:00<00:00, 28032.91it/s]
# Cleaning and Matching Firms for Belarus: 100%|██████████| 132/132 [00:00<00:00, 18207.32it/s]
# Cleaning and Matching Firms for Belize: 100%|██████████| 62/62 [00:00<00:00, 25895.92it/s]
# Cleaning and Matching Firms for Bermuda: 100%|██████████| 34/34 [00:00<00:00, 30387.03it/s]
# Cleaning and Matching Firms for Bolivia: 100%|██████████| 111/111 [00:00<00:00, 19677.42it/s]
# Cleaning and Matching Firms for Brazil: 100%|██████████| 3468/3468 [00:02<00:00, 1377.83it/s]
# Cleaning and Matching Firms for Barbados: 100%|██████████| 61/61 [00:00<00:00, 26112.73it/s]
# Cleaning and Matching Firms for Brunei Darussalam: 100%|██████████| 703/703 [00:00<00:00, 5144.64it/s]
# Cleaning and Matching Firms for Bhutan: 100%|██████████| 18/18 [00:00<00:00, 29711.72it/s]
# Cleaning and Matching Firms for Botswana: 100%|██████████| 23/23 [00:00<00:00, 26590.13it/s]
# Cleaning and Matching Firms for Central African Republic: 100%|██████████| 19/19 [00:00<00:00, 29330.80it/s]
# Cleaning and Matching Firms for Canada: 100%|██████████| 6124/6124 [00:09<00:00, 626.30it/s]
# Cleaning and Matching Firms for Switzerland: 100%|██████████| 3914/3914 [00:03<00:00, 1121.98it/s]
# Cleaning and Matching Firms for Chile: 100%|██████████| 1112/1112 [00:00<00:00, 3623.86it/s]
# Cleaning and Matching Firms for China: 100%|██████████| 136276/136276 [1:02:52<00:00, 36.12it/s]
# Cleaning and Matching Firms for Cote d'Ivoire: 100%|██████████| 235/235 [00:00<00:00, 7755.01it/s]
# Cleaning and Matching Firms for Cameroon: 100%|██████████| 219/219 [00:00<00:00, 11311.39it/s]
# Cleaning and Matching Firms for Congo: 100%|██████████| 184/184 [00:00<00:00, 13203.40it/s]
# Cleaning and Matching Firms for Cook Islands: 100%|██████████| 27/27 [00:00<00:00, 21719.64it/s]
# Cleaning and Matching Firms for Colombia: 100%|██████████| 863/863 [00:00<00:00, 4278.69it/s]
# Cleaning and Matching Firms for Comoros: 100%|██████████| 32/32 [00:00<00:00, 25915.76it/s]
# Cleaning and Matching Firms for Cape Verde: 100%|██████████| 18/18 [00:00<00:00, 25385.83it/s]
# Cleaning and Matching Firms for Costa Rica: 100%|██████████| 290/290 [00:00<00:00, 9877.12it/s]
# Cleaning and Matching Firms for Cuba: 100%|██████████| 28/28 [00:00<00:00, 20420.89it/s]
# Cleaning and Matching Firms for Curacao: 100%|██████████| 6/6 [00:00<00:00, 12396.96it/s]
# Cleaning and Matching Firms for Christmas Island: 100%|██████████| 3/3 [00:00<00:00, 6223.00it/s]
# Cleaning and Matching Firms for Cayman Islands: 100%|██████████| 37/37 [00:00<00:00, 31755.52it/s]
# Cleaning and Matching Firms for Cyprus: 100%|██████████| 302/302 [00:00<00:00, 4058.65it/s]
# Cleaning and Matching Firms for Czech Republic: 100%|██████████| 1243/1243 [00:00<00:00, 2801.51it/s]
# Cleaning and Matching Firms for Germany: 100%|██████████| 20708/20708 [01:57<00:00, 176.89it/s]
# Cleaning and Matching Firms for Djibouti: 100%|██████████| 121/121 [00:00<00:00, 13936.86it/s]
# Cleaning and Matching Firms for Dominica: 100%|██████████| 25/25 [00:00<00:00, 25358.55it/s]
# Cleaning and Matching Firms for Denmark: 100%|██████████| 2054/2054 [00:01<00:00, 1917.71it/s]
# Cleaning and Matching Firms for Dominican Republic: 100%|██████████| 405/405 [00:00<00:00, 7684.17it/s]
# Cleaning and Matching Firms for Algeria: 100%|██████████| 407/407 [00:00<00:00, 6853.58it/s]
# Cleaning and Matching Firms for Ecuador: 100%|██████████| 537/537 [00:00<00:00, 6123.77it/s]
# Cleaning and Matching Firms for Egypt: 100%|██████████| 2202/2202 [00:01<00:00, 1825.92it/s]
# Cleaning and Matching Firms for Eritrea: 100%|██████████| 7/7 [00:00<00:00, 15559.16it/s]
# Cleaning and Matching Firms for Spain: 100%|██████████| 6201/6201 [00:11<00:00, 528.49it/s]
# Cleaning and Matching Firms for Estonia: 100%|██████████| 208/208 [00:00<00:00, 12044.11it/s]
# Cleaning and Matching Firms for Ethiopia: 100%|██████████| 402/402 [00:00<00:00, 7573.19it/s]
# Cleaning and Matching Firms for Finland: 100%|██████████| 1133/1133 [00:00<00:00, 3099.97it/s]
# Cleaning and Matching Firms for Fiji: 100%|██████████| 414/414 [00:00<00:00, 7351.73it/s]
# Cleaning and Matching Firms for France: 100%|██████████| 9520/9520 [00:24<00:00, 395.77it/s]
# Cleaning and Matching Firms for Faroe Islands: 100%|██████████| 2/2 [00:00<00:00, 3407.23it/s]
# Cleaning and Matching Firms for Micronesia, Federated States of: 100%|██████████| 32/32 [00:00<00:00, 28520.55it/s]
# Cleaning and Matching Firms for Gabon: 100%|██████████| 119/119 [00:00<00:00, 15490.59it/s]
# Cleaning and Matching Firms for United Kingdom: 100%|██████████| 13095/13095 [00:45<00:00, 288.67it/s]
# Cleaning and Matching Firms for Georgia: 100%|██████████| 215/215 [00:00<00:00, 10804.10it/s]
# Cleaning and Matching Firms for Guernsey: 100%|██████████| 3/3 [00:00<00:00, 8149.55it/s]
# Cleaning and Matching Firms for Ghana: 100%|██████████| 467/467 [00:00<00:00, 6578.41it/s]
# Cleaning and Matching Firms for Gibraltar: 100%|██████████| 10/10 [00:00<00:00, 11946.18it/s]
# Cleaning and Matching Firms for Guinea: 100%|██████████| 106/106 [00:00<00:00, 20622.30it/s]
# Cleaning and Matching Firms for Guadeloupe: 100%|██████████| 158/158 [00:00<00:00, 13315.52it/s]
# Cleaning and Matching Firms for Gambia: 100%|██████████| 64/64 [00:00<00:00, 23873.66it/s]
# Cleaning and Matching Firms for Guinea-Bissau: 100%|██████████| 8/8 [00:00<00:00, 13076.55it/s]
# Cleaning and Matching Firms for Equatorial Guinea: 100%|██████████| 27/27 [00:00<00:00, 17822.82it/s]
# Cleaning and Matching Firms for Greece: 100%|██████████| 1564/1564 [00:00<00:00, 2169.15it/s]
# Cleaning and Matching Firms for Grenada: 100%|██████████| 16/16 [00:00<00:00, 22534.88it/s]
# Cleaning and Matching Firms for Greenland: 100%|██████████| 2/2 [00:00<00:00, 6345.39it/s]
# Cleaning and Matching Firms for Guatemala: 100%|██████████| 348/348 [00:00<00:00, 8997.60it/s]
# Cleaning and Matching Firms for French Guiana: 100%|██████████| 21/21 [00:00<00:00, 22248.14it/s]
# Cleaning and Matching Firms for Guam: 100%|██████████| 67/67 [00:00<00:00, 24092.80it/s]
# Cleaning and Matching Firms for Guyana: 100%|██████████| 59/59 [00:00<00:00, 23868.05it/s]
# Cleaning and Matching Firms for Hong Kong: 100%|██████████| 29323/29323 [03:17<00:00, 148.69it/s]
# Cleaning and Matching Firms for Honduras: 100%|██████████| 182/182 [00:00<00:00, 2760.38it/s]
# Cleaning and Matching Firms for Croatia: 100%|██████████| 363/363 [00:00<00:00, 2766.43it/s]
# Cleaning and Matching Firms for Haiti: 100%|██████████| 101/101 [00:00<00:00, 6282.34it/s]
# Cleaning and Matching Firms for Hungary: 100%|██████████| 674/674 [00:00<00:00, 2071.59it/s]
# Cleaning and Matching Firms for Indonesia: 100%|██████████| 756/756 [00:00<00:00, 1310.08it/s]
# Cleaning and Matching Firms for Isle of Man: 100%|██████████| 11/11 [00:00<00:00, 2219.10it/s]
# Cleaning and Matching Firms for India: 100%|██████████| 23453/23453 [02:19<00:00, 168.51it/s]
# Cleaning and Matching Firms for British Indian Ocean Territory: 100%|██████████| 2/2 [00:00<00:00, 653.57it/s]
# Cleaning and Matching Firms for Ireland: 100%|██████████| 899/899 [00:00<00:00, 3569.15it/s]
# Cleaning and Matching Firms for Iraq: 100%|██████████| 536/536 [00:00<00:00, 5586.53it/s]
# Cleaning and Matching Firms for Iceland: 100%|██████████| 48/48 [00:00<00:00, 24131.20it/s]
# Cleaning and Matching Firms for Israel: 100%|██████████| 1114/1114 [00:00<00:00, 3149.86it/s]
# Cleaning and Matching Firms for Italy: 100%|██████████| 13618/13618 [00:44<00:00, 304.56it/s]
# Cleaning and Matching Firms for Jamaica: 100%|██████████| 132/132 [00:00<00:00, 14300.98it/s]
# Cleaning and Matching Firms for Jersey: 100%|██████████| 1/1 [00:00<00:00, 1550.57it/s]
# Cleaning and Matching Firms for Jordan: 100%|██████████| 717/717 [00:00<00:00, 4369.31it/s]
# Cleaning and Matching Firms for Japan: 100%|██████████| 25900/25900 [02:35<00:00, 166.55it/s]
# Cleaning and Matching Firms for Kazakhstan: 100%|██████████| 162/162 [00:00<00:00, 7238.57it/s]
# Cleaning and Matching Firms for Kenya: 100%|██████████| 649/649 [00:00<00:00, 4742.10it/s]
# Cleaning and Matching Firms for Kyrgyzstan: 100%|██████████| 15/15 [00:00<00:00, 11913.38it/s]
# Cleaning and Matching Firms for Cambodia: 100%|██████████| 1113/1113 [00:00<00:00, 3162.88it/s]
# Cleaning and Matching Firms for Kiribati: 100%|██████████| 43/43 [00:00<00:00, 25416.44it/s]
# Cleaning and Matching Firms for Saint Kitts and Nevis: 100%|██████████| 18/18 [00:00<00:00, 26196.21it/s]
# Cleaning and Matching Firms for Kuwait: 100%|██████████| 1027/1027 [00:00<00:00, 3401.10it/s]
# Cleaning and Matching Firms for Laos: 100%|██████████| 133/133 [00:00<00:00, 17205.68it/s]
# Cleaning and Matching Firms for Lebanon: 100%|██████████| 694/694 [00:00<00:00, 3741.78it/s]
# Cleaning and Matching Firms for Liberia: 100%|██████████| 82/82 [00:00<00:00, 21715.68it/s]
# Cleaning and Matching Firms for Libya: 100%|██████████| 275/275 [00:00<00:00, 9246.55it/s]
# Cleaning and Matching Firms for Saint Lucia: 100%|██████████| 27/27 [00:00<00:00, 22153.01it/s]
# Cleaning and Matching Firms for Liechtenstein: 100%|██████████| 23/23 [00:00<00:00, 566.10it/s]
# Cleaning and Matching Firms for Sri Lanka: 100%|██████████| 2073/2073 [00:01<00:00, 1777.11it/s]
# Cleaning and Matching Firms for Lesotho: 100%|██████████| 10/10 [00:00<00:00, 13037.94it/s]
# Cleaning and Matching Firms for Lithuania: 100%|██████████| 334/334 [00:00<00:00, 8281.30it/s]
# Cleaning and Matching Firms for Luxembourg: 100%|██████████| 212/212 [00:00<00:00, 15046.07it/s]
# Cleaning and Matching Firms for Latvia: 100%|██████████| 256/256 [00:00<00:00, 9212.95it/s]
# Cleaning and Matching Firms for Macau: 100%|██████████| 279/279 [00:00<00:00, 10019.44it/s]
# Cleaning and Matching Firms for Morocco: 100%|██████████| 596/596 [00:00<00:00, 4278.87it/s]
# Cleaning and Matching Firms for Monaco: 100%|██████████| 61/61 [00:00<00:00, 25039.40it/s]
# Cleaning and Matching Firms for Moldova, Republic of: 100%|██████████| 74/74 [00:00<00:00, 24034.26it/s]
# Cleaning and Matching Firms for Madagascar: 100%|██████████| 238/238 [00:00<00:00, 10574.51it/s]
# Cleaning and Matching Firms for Maldives: 100%|██████████| 1111/1111 [00:00<00:00, 3025.05it/s]
# Cleaning and Matching Firms for Mexico: 100%|██████████| 2840/2840 [00:01<00:00, 1436.31it/s]
# Cleaning and Matching Firms for Marshall Islands: 100%|██████████| 132/132 [00:00<00:00, 16234.11it/s]
# Cleaning and Matching Firms for Macedonia: 100%|██████████| 66/66 [00:00<00:00, 19047.96it/s]
# Cleaning and Matching Firms for Mali: 100%|██████████| 70/70 [00:00<00:00, 18310.03it/s]
# Cleaning and Matching Firms for Malta: 100%|██████████| 164/164 [00:00<00:00, 11241.11it/s]
# Cleaning and Matching Firms for Myanmar: 100%|██████████| 1562/1562 [00:01<00:00, 1187.71it/s]
# Cleaning and Matching Firms for Montenegro: 100%|██████████| 53/53 [00:00<00:00, 6778.21it/s]
# Cleaning and Matching Firms for Mongolia: 100%|██████████| 121/121 [00:00<00:00, 7031.18it/s]
# Cleaning and Matching Firms for Northern Mariana Islands: 100%|██████████| 15/15 [00:00<00:00, 6738.20it/s]
# Cleaning and Matching Firms for Mozambique: 100%|██████████| 209/209 [00:00<00:00, 5174.91it/s]
# Cleaning and Matching Firms for Mauritania: 100%|██████████| 70/70 [00:00<00:00, 6056.51it/s]
# Cleaning and Matching Firms for Montserrat: 100%|██████████| 1/1 [00:00<00:00, 1630.76it/s]
# Cleaning and Matching Firms for Martinique: 100%|██████████| 84/84 [00:00<00:00, 4360.68it/s]
# Cleaning and Matching Firms for Mauritius: 100%|██████████| 754/754 [00:00<00:00, 2068.50it/s]
# Cleaning and Matching Firms for Malawi: 100%|██████████| 72/72 [00:00<00:00, 7785.45it/s]
# Cleaning and Matching Firms for Malaysia: 100%|██████████| 24691/24691 [02:08<00:00, 192.82it/s]
# Cleaning and Matching Firms for Mayotte: 100%|██████████| 34/34 [00:00<00:00, 13704.24it/s]
# Cleaning and Matching Firms for Namibia: 100%|██████████| 40/40 [00:00<00:00, 28206.48it/s]
# Cleaning and Matching Firms for New Caledonia: 100%|██████████| 273/273 [00:00<00:00, 3484.75it/s]
# Cleaning and Matching Firms for Niger: 100%|██████████| 42/42 [00:00<00:00, 23024.54it/s]
# Cleaning and Matching Firms for Norfolk Island: 100%|██████████| 3/3 [00:00<00:00, 9313.78it/s]
# Cleaning and Matching Firms for Nigeria: 100%|██████████| 1047/1047 [00:00<00:00, 3243.88it/s]
# Cleaning and Matching Firms for Nicaragua: 100%|██████████| 117/117 [00:00<00:00, 18630.74it/s]
# Cleaning and Matching Firms for Netherlands: 100%|██████████| 9069/9069 [00:20<00:00, 435.28it/s]
# Cleaning and Matching Firms for Norway: 100%|██████████| 963/963 [00:00<00:00, 3126.22it/s]
# Cleaning and Matching Firms for Nepal: 100%|██████████| 512/512 [00:00<00:00, 6552.84it/s]
# Cleaning and Matching Firms for Nauru: 100%|██████████| 24/24 [00:00<00:00, 23056.18it/s]
# Cleaning and Matching Firms for New Zealand: 100%|██████████| 3141/3141 [00:02<00:00, 1286.89it/s]
# Cleaning and Matching Firms for Oman: 100%|██████████| 845/845 [00:00<00:00, 4143.40it/s]
# Cleaning and Matching Firms for OTH: 100%|██████████| 321/321 [00:00<00:00, 3973.32it/s]
# Cleaning and Matching Firms for Pakistan: 100%|██████████| 4533/4533 [00:04<00:00, 1011.57it/s]
# Cleaning and Matching Firms for Panama: 100%|██████████| 583/583 [00:00<00:00, 6093.87it/s]
# Cleaning and Matching Firms for Peru: 100%|██████████| 859/859 [00:00<00:00, 4223.93it/s]
# Cleaning and Matching Firms for Philippines: 100%|██████████| 6034/6034 [00:09<00:00, 653.28it/s]
# Cleaning and Matching Firms for Palau: 100%|██████████| 10/10 [00:00<00:00, 11878.52it/s]
# Cleaning and Matching Firms for Papua New Guinea: 100%|██████████| 479/479 [00:00<00:00, 7101.35it/s]
# Cleaning and Matching Firms for Poland: 100%|██████████| 2206/2206 [00:01<00:00, 1920.68it/s]
# Cleaning and Matching Firms for Puerto Rico: 100%|██████████| 175/175 [00:00<00:00, 14799.05it/s]
# Cleaning and Matching Firms for North Korea: 100%|██████████| 7/7 [00:00<00:00, 14702.12it/s]
# Cleaning and Matching Firms for Portugal: 100%|██████████| 1018/1018 [00:00<00:00, 3415.81it/s]
# Cleaning and Matching Firms for Paraguay: 100%|██████████| 154/154 [00:00<00:00, 16381.09it/s]
# Cleaning and Matching Firms for Palestine: 100%|██████████| 61/61 [00:00<00:00, 17691.37it/s]
# Cleaning and Matching Firms for French Polynesia: 100%|██████████| 269/269 [00:00<00:00, 10231.31it/s]
# Cleaning and Matching Firms for Qatar: 100%|██████████| 1084/1084 [00:00<00:00, 2946.64it/s]
# Cleaning and Matching Firms for Reunion: 100%|██████████| 318/318 [00:00<00:00, 9380.85it/s]
# Cleaning and Matching Firms for Romania: 100%|██████████| 617/617 [00:00<00:00, 5334.20it/s]
# Cleaning and Matching Firms for Russia: 100%|██████████| 2540/2540 [00:01<00:00, 1524.52it/s]
# Cleaning and Matching Firms for Rwanda: 100%|██████████| 84/84 [00:00<00:00, 22317.19it/s]
# Cleaning and Matching Firms for Saudi Arabia: 100%|██████████| 3342/3342 [00:02<00:00, 1148.87it/s]
# Cleaning and Matching Firms for Sudan: 100%|██████████| 510/510 [00:00<00:00, 6542.68it/s]
# Cleaning and Matching Firms for Senegal: 100%|██████████| 217/217 [00:00<00:00, 11532.74it/s]
# Cleaning and Matching Firms for Singapore: 100%|██████████| 36007/36007 [04:22<00:00, 137.38it/s]
# Cleaning and Matching Firms for St. Helena: 100%|██████████| 3/3 [00:00<00:00, 1801.68it/s]
# Cleaning and Matching Firms for Solomon Islands: 100%|██████████| 82/82 [00:00<00:00, 12439.25it/s]
# Cleaning and Matching Firms for Sierra Leone: 100%|██████████| 61/61 [00:00<00:00, 18413.28it/s]
# Cleaning and Matching Firms for El Salvador: 100%|██████████| 190/190 [00:00<00:00, 11561.26it/s]
# Cleaning and Matching Firms for San Marino: 100%|██████████| 11/11 [00:00<00:00, 14921.52it/s]
# Cleaning and Matching Firms for Somalia: 100%|██████████| 321/321 [00:00<00:00, 3812.03it/s]
# Cleaning and Matching Firms for Serbia: 100%|██████████| 233/233 [00:00<00:00, 12534.28it/s]
# Cleaning and Matching Firms for South Sudan: 100%|██████████| 2/2 [00:00<00:00, 4999.17it/s]
# Cleaning and Matching Firms for Sao Tome and Principe: 100%|██████████| 15/15 [00:00<00:00, 23994.87it/s]
# Cleaning and Matching Firms for Suriname: 100%|██████████| 114/114 [00:00<00:00, 17487.13it/s]
# Cleaning and Matching Firms for Slovakia: 100%|██████████| 306/306 [00:00<00:00, 10159.00it/s]
# Cleaning and Matching Firms for Slovenia: 100%|██████████| 412/412 [00:00<00:00, 7254.81it/s]
# Cleaning and Matching Firms for Sweden: 100%|██████████| 2253/2253 [00:01<00:00, 1769.44it/s]
# Cleaning and Matching Firms for Swaziland: 100%|██████████| 81/81 [00:00<00:00, 22652.26it/s]
# Cleaning and Matching Firms for Seychelles: 100%|██████████| 276/276 [00:00<00:00, 10283.90it/s]
# Cleaning and Matching Firms for Syria: 100%|██████████| 94/94 [00:00<00:00, 21578.71it/s]
# Cleaning and Matching Firms for Turks and Caicos Islands: 100%|██████████| 21/21 [00:00<00:00, 24224.53it/s]
# Cleaning and Matching Firms for Chad: 100%|██████████| 24/24 [00:00<00:00, 34831.59it/s]
# Cleaning and Matching Firms for Togo: 100%|██████████| 218/218 [00:00<00:00, 9325.43it/s]
# Cleaning and Matching Firms for Thailand: 100%|██████████| 15153/15153 [00:57<00:00, 264.93it/s]
# Cleaning and Matching Firms for Tajikistan: 100%|██████████| 9/9 [00:00<00:00, 5685.05it/s]
# Cleaning and Matching Firms for Tokelau: 100%|██████████| 3/3 [00:00<00:00, 6594.82it/s]
# Cleaning and Matching Firms for Turkmenistan: 100%|██████████| 21/21 [00:00<00:00, 14432.31it/s]
# Cleaning and Matching Firms for East Timor: 100%|██████████| 1342/1342 [00:00<00:00, 2531.27it/s]
# Cleaning and Matching Firms for Tonga: 100%|██████████| 50/50 [00:00<00:00, 22182.70it/s]
# Cleaning and Matching Firms for Trinidad and Tobago: 100%|██████████| 127/127 [00:00<00:00, 6624.51it/s]
# Cleaning and Matching Firms for Tunisia: 100%|██████████| 308/308 [00:00<00:00, 7565.09it/s]
# Cleaning and Matching Firms for Turkey: 100%|██████████| 6169/6169 [00:09<00:00, 650.79it/s]
# Cleaning and Matching Firms for Tuvalu: 100%|██████████| 8/8 [00:00<00:00, 14979.66it/s]
# Cleaning and Matching Firms for Taiwan: 100%|██████████| 22286/22286 [01:50<00:00, 201.98it/s]
# Cleaning and Matching Firms for Uganda: 100%|██████████| 180/180 [00:00<00:00, 13156.08it/s]
# Cleaning and Matching Firms for Ukraine: 100%|██████████| 803/803 [00:00<00:00, 4088.47it/s]
# Cleaning and Matching Firms for United States Minor Outlying Islands: 100%|██████████| 1/1 [00:00<00:00, 2054.02it/s]
# Cleaning and Matching Firms for Uruguay: 100%|██████████| 326/326 [00:00<00:00, 8665.86it/s]
# Cleaning and Matching Firms for United States: 100%|██████████| 52377/52377 [14:51<00:00, 58.72it/s]
# Cleaning and Matching Firms for Uzbekistan: 100%|██████████| 139/139 [00:00<00:00, 5051.19it/s]
# Cleaning and Matching Firms for Vatican City State (Holy See): 100%|██████████| 6/6 [00:00<00:00, 1435.75it/s]
# Cleaning and Matching Firms for Saint Vincent and the Grenadines: 100%|██████████| 21/21 [00:00<00:00, 14788.51it/s]
# Cleaning and Matching Firms for Venezuela: 100%|██████████| 132/132 [00:00<00:00, 7760.70it/s]
# Cleaning and Matching Firms for Virgin Islands (British): 100%|██████████| 217/217 [00:00<00:00, 2726.72it/s]
# Cleaning and Matching Firms for Virgin Islands (U.S.): 100%|██████████| 52/52 [00:00<00:00, 17580.51it/s]
# Cleaning and Matching Firms for Vietnam: 100%|██████████| 17507/17507 [01:36<00:00, 180.71it/s]
# Cleaning and Matching Firms for Vanuatu: 100%|██████████| 99/99 [00:00<00:00, 16322.82it/s]
# Cleaning and Matching Firms for Wallis and Futuna Islands: 100%|██████████| 4/4 [00:00<00:00, 6369.48it/s]
# Cleaning and Matching Firms for Republic of Kosovo: 100%|██████████| 1/1 [00:00<00:00, 1814.93it/s]
# Cleaning and Matching Firms for Yemen: 100%|██████████| 337/337 [00:00<00:00, 7317.02it/s]
# Cleaning and Matching Firms for South Africa: 100%|██████████| 2682/2682 [00:02<00:00, 1036.03it/s]
# Cleaning and Matching Firms for Zambia: 100%|██████████| 64/64 [00:00<00:00, 15212.26it/s]
# Cleaning and Matching Firms for Zimbabwe: 100%|██████████| 76/76 [00:00<00:00, 16580.00it/s]
# Processing by Country: 100%|██████████| 229/229 [1:43:46<00:00, 27.19s/it]
#                                  foreign foreigncountry_cleaned  shpmtyear  \
# 0               Home & Nature Unicon N.V                  Aruba       2019
# 1                     Gca Auto Sales N V                  Aruba       2019
# 2            Tricen Maintenance Services                  Aruba       2019
# 3                     Gca Auto Sales N V                  Aruba       2020
# 4                        Osyth Henriquez                  Aruba       2019
# 5               Landglass Distibutor Ind                  Aruba       2020
# 6              Simple Beauty Trading N V                  Aruba       2019
# 7               Home & Nature Unicon N.V                  Aruba       2020
# 8   R.E. Yrausquin And Sons (Aruba) N.V.                  Aruba       2020
# 9               Ultimate Automobiles N V                  Aruba       2019
# 10                 W G Den Heijer Zn B V                  Aruba       2020
# 11                Home Nature Unicon N V                  Aruba       2020
# 12                                   NaN                  Aruba       2020
# 13                  Maspralto Enterprise                  Aruba       2019
# 14               Bon Bini Cargo Services                  Aruba       2019
# 15                             Boardwalk                  Aruba       2019
# 16              Ultimate Automobiles N V                  Aruba       2020
# 17                                   NaN                  Aruba       2019
# 18                              Banjolux                  Aruba       2020
# 19              Landglass Distibutor Ind                  Aruba       2019
#
#    country_name country_iso3                      cleaned_name cleaned_ID  \
# 0         Aruba          ABW           Home & Nature Unicon Nv      1_ABW
# 1         Aruba          ABW                Gca Auto Sales N V      2_ABW
# 2         Aruba          ABW       Tricen Maintenance Services      3_ABW
# 3         Aruba          ABW                Gca Auto Sales N V      2_ABW
# 4         Aruba          ABW                   Osyth Henriquez      4_ABW
# 5         Aruba          ABW          Landglass Distibutor Ind      5_ABW
# 6         Aruba          ABW         Simple Beauty Trading N V      6_ABW
# 7         Aruba          ABW           Home & Nature Unicon Nv      1_ABW
# 8         Aruba          ABW  Re Yrausquin And Sons (Aruba) Nv      7_ABW
# 9         Aruba          ABW          Ultimate Automobiles N V      8_ABW
# 10        Aruba          ABW             W G Den Heijer Zn B V      9_ABW
# 11        Aruba          ABW           Home & Nature Unicon Nv      1_ABW
# 12        Aruba          ABW                                       10_ABW
# 13        Aruba          ABW              Maspralto Enterprise     11_ABW
# 14        Aruba          ABW           Bon Bini Cargo Services     12_ABW
# 15        Aruba          ABW                         Boardwalk     13_ABW
# 16        Aruba          ABW          Ultimate Automobiles N V      8_ABW
# 17        Aruba          ABW                                       14_ABW
# 18        Aruba          ABW                          Banjolux     15_ABW
# 19        Aruba          ABW          Landglass Distibutor Ind      5_ABW
#
#     matching_score
# 0                0
# 1                0
# 2                0
# 3              100
# 4                0
# 5                0
# 6                0
# 7              100
# 8                0
# 9                0
# 10               0
# 11              89
# 12               0
# 13               0
# 14               0
# 15               0
# 16             100
# 17               0
# 18               0
# 19             100

# %% [markdown]
# + Divide the Data into Training and Test Sets and Apply Machine Learning: First, divide the cleaned data into training and test sets, typically using 70% for training and 30% for testing. Apply your initial cleaning algorithm to the training data, and then manually review and correct any errors in the cleaned names. Develop a machine learning model to predict the cleaned firm names (cleaned_name) based on the manually corrected training data. The variable to be predicted with the ML algorithm is the cleaned_name, as the goal is to standardize and accurately identify firm names despite inconsistencies in the original entries. Apply the trained model to the test data to see if it can generalize the cleaning rules and corrections. Finally, compare the accuracy of the cleaned names in the test data before and after applying the machine learning model by measuring the proportion of correctly predicted cleaned names. Comment on whether the accuracy has increased after applying the machine learning algorithm.
#
# + Include the output in a csv file that you will name outputfile_yourfirstname_1 (this file will include all the observations and all the fields in the ForeignNames_2019_2020.csv dataset + a variable called “cleaned_ID” (which is the ID you have given) + a variable called “cleaned_name” (the firm name you have given)).
#
# + Construct also a csv file that you will name outputfile_yourfirstname_1_changed that includes ONLY the firm names that have changed as a result of your cleaning + the original firm name that cleaned firm names changed to. In our example, this will be a dataset with all the “Teaboard” firms. Teaboard LTd, Teaboar Ld are the firm names that have changed as a result of the cleaning while Teaboard Limited is the original firm name that cleaned firm names changed to. Please do NOT include in this file those firms whose names have not changed).

# %%
import os
import pandas as pd
from fuzzywuzzy import fuzz
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score
from IPython.display import display

# Now, divide the data into training and test sets
# Load the cleaned dataset
cleaned_df = pd.read_csv('Cleaned_ForeignNames_2019_2020.csv')

# Drop rows with NaN values in 'foreign' and 'cleaned_name'
cleaned_df = cleaned_df.dropna(subset=['foreign', 'cleaned_name'])

# Define features and labels
X = cleaned_df['foreign']  # Original names
y = cleaned_df['cleaned_name']  # Cleaned names

# Split the data into training (70%) and testing (30%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Develop and train a machine learning model
model = make_pipeline(TfidfVectorizer(), MultinomialNB())
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}")

# Apply the model to the entire dataset to predict cleaned names
cleaned_df['cleaned_name_pred'] = model.predict(cleaned_df['foreign'])

# Save the output file with all observations and fields
cleaned_df.to_csv('outputfile_Jairo_1.csv', index=False)

# Construct a CSV file with only the firm names that have changed after applying the ML model
changed_names = cleaned_df[cleaned_df['cleaned_name'] != cleaned_df['cleaned_name_pred']]
changed_names.to_csv('outputfile_Jairo_1_changed.csv', index=False)

# Display samples of the output
display(cleaned_df.head())
display(changed_names.head())
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# # Part 2

# %% [markdown]
# Use ForeignNames_2021.csv for the following tasks:

# %% [markdown]
# + You did all the above cleaning work using a list of firm names until 2020. But the data on foreign names keeps getting updated, so now you need to expand the list of firm names to go up to 2021. You need to clean the names and assign the same IDs to firms that already exist prior to 2021 and new IDs to firms that appear just in 2021. For example, if Teaboard Ltd appears in 2021, it will get the same ID as before (2214, prefixed by the country 3-digit ISO codes). It is important to note that we again want all variations of Teaboard Ltd. to get the same unique ID just like before.
#
# + The output from this task should be a file with all the original firm names, the variable “cleaned_name”, the variable “cleaned_ID”, a binary variable called “new” (taking value 1 if the firm name is new in 2021 and 0 otherwise). If the variable “new” takes a value 0, please include the name of the firm from the older data (i.e. the 2019-2020 data) in a variable called “old_name”. Obviously, both the old and new IDs should be the same.
#
# + Include the output in a csv file that you will name outputfile_yourfirstname_2

# %%
import os
import pandas as pd
from fuzzywuzzy import fuzz
from tqdm import tqdm

# Set the working directory
os.chdir('/Users/jairogalvis/Downloads/PythonRStataTest2024/PythonTest/')

# Load the datasets
foreign_names_2021 = pd.read_csv('ForeignNames_2021.csv')
print(f"ForeignNames_2021 shape: {foreign_names_2021.shape}")
cleaned_df_2019_2020 = pd.read_csv('Cleaned_ForeignNames_2019_2020.csv')
print(f"Cleaned_ForeignNames_2019_2020 shape: {cleaned_df_2019_2020.shape}")
country_mapping = pd.read_csv('Country_Name_ISO3.csv')

# Clean 'Country_Name_ISO3.csv'
country_mapping_cleaned = country_mapping[country_mapping['country_name'].notna() & (country_mapping['country_name'].str.strip() != '')]
foreign_names_2021['foreigncountry_cleaned'] = foreign_names_2021['foreigncountry_cleaned'].str.strip()
country_mapping_cleaned['country_name'] = country_mapping_cleaned['country_name'].str.strip()

# Merge the 2021 data with country names
foreign_names_2021 = foreign_names_2021.merge(country_mapping_cleaned, left_on='foreigncountry_cleaned', right_on='country_name', how='left')

# Create a dictionary for cleaned IDs from 2019-2020 data
id_map = pd.Series(cleaned_df_2019_2020['cleaned_ID'].values, index=cleaned_df_2019_2020['cleaned_name']).to_dict()

# Function to clean firm names
def clean_name(name):
    if isinstance(name, str):
        name = name.lower()
        name = name.replace('.', '').replace(',', '')  # Remove periods and commas
        name = ' '.join(name.split())  # Remove extra spaces
        return name.title()
    return ''

# Clean and assign IDs to the 2021 data
def assign_id_and_name(df):
    cleaned_names = {}
    existing_ids = [int(id.split('_')[1]) for id in id_map.values() if id.split('_')[1].isdigit()]
    unique_id = max(existing_ids, default=0) + 1
    
    cleaned_name_list = []
    cleaned_id_list = []
    new_list = []
    old_name_list = []
    
    for index, row in tqdm(df.iterrows(), total=df.shape[0], desc=f"Processing Firms for {df['country_iso3'].iloc[0]}"):
        original_name = row['foreign']
        cleaned_name = clean_name(original_name)
        
        if cleaned_name in id_map:
            # Existing firm, use old ID
            cleaned_name_list.append(cleaned_name)
            cleaned_id_list.append(id_map[cleaned_name])
            new_list.append(0)
            old_name_list.append(cleaned_name)  # Keep the cleaned name as old name
        else:
            # New firm, assign a new ID
            cleaned_names[cleaned_name] = f"{df['country_iso3'].iloc[0]}_{unique_id}"
            cleaned_name_list.append(cleaned_name)
            cleaned_id_list.append(cleaned_names[cleaned_name])
            new_list.append(1)
            old_name_list.append('')  # No old name for new firms
            unique_id += 1
    
    df['cleaned_name'] = cleaned_name_list
    df['cleaned_ID'] = cleaned_id_list
    df['new'] = new_list
    df['old_name'] = old_name_list
    
    return df

# Combine the old and new datasets
combined_df = pd.concat([cleaned_df_2019_2020, foreign_names_2021], ignore_index=True)

# Process the combined dataset
processed_combined_df = assign_id_and_name(combined_df)

# Save the combined output to CSV
processed_combined_df.to_csv('Cleaned_ForeignNames_2019_2021.csv', index=False)

# Display a sample of the output
print(f"Whole dataset shape: {processed_combined_df.shape}")
display(processed_combined_df.head(20))
# Out:
# ForeignNames_2021 shape: (249656, 3)
# Cleaned_ForeignNames_2019_2020 shape: (594032, 8)
# /var/folders/bg/2pq2ytns0s7fgw4rcxpv0szw0000gn/T/ipykernel_93095/1113511913.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   country_mapping_cleaned['country_name'] = country_mapping_cleaned['country_name'].str.strip()
# Processing Firms for ABW: 100%|██████████| 843688/843688 [00:19<00:00, 43972.55it/s]
# Whole dataset shape: (843688, 10)
#                                  foreign foreigncountry_cleaned  shpmtyear  \
# 0               Home & Nature Unicon N.V                  Aruba       2019
# 1                     Gca Auto Sales N V                  Aruba       2019
# 2            Tricen Maintenance Services                  Aruba       2019
# 3                     Gca Auto Sales N V                  Aruba       2020
# 4                        Osyth Henriquez                  Aruba       2019
# 5               Landglass Distibutor Ind                  Aruba       2020
# 6              Simple Beauty Trading N V                  Aruba       2019
# 7               Home & Nature Unicon N.V                  Aruba       2020
# 8   R.E. Yrausquin And Sons (Aruba) N.V.                  Aruba       2020
# 9               Ultimate Automobiles N V                  Aruba       2019
# 10                 W G Den Heijer Zn B V                  Aruba       2020
# 11                Home Nature Unicon N V                  Aruba       2020
# 12                                   NaN                  Aruba       2020
# 13                  Maspralto Enterprise                  Aruba       2019
# 14               Bon Bini Cargo Services                  Aruba       2019
# 15                             Boardwalk                  Aruba       2019
# 16              Ultimate Automobiles N V                  Aruba       2020
# 17                                   NaN                  Aruba       2019
# 18                              Banjolux                  Aruba       2020
# 19              Landglass Distibutor Ind                  Aruba       2019
#
#    country_name country_iso3                      cleaned_name cleaned_ID  \
# 0         Aruba          ABW           Home & Nature Unicon Nv      1_ABW
# 1         Aruba          ABW                Gca Auto Sales N V      2_ABW
# 2         Aruba          ABW       Tricen Maintenance Services      3_ABW
# 3         Aruba          ABW                Gca Auto Sales N V      2_ABW
# 4         Aruba          ABW                   Osyth Henriquez      4_ABW
# 5         Aruba          ABW          Landglass Distibutor Ind      5_ABW
# 6         Aruba          ABW         Simple Beauty Trading N V      6_ABW
# 7         Aruba          ABW           Home & Nature Unicon Nv      1_ABW
# 8         Aruba          ABW  Re Yrausquin And Sons (Aruba) Nv      7_ABW
# 9         Aruba          ABW          Ultimate Automobiles N V      8_ABW
# 10        Aruba          ABW             W G Den Heijer Zn B V    766_NLD
# 11        Aruba          ABW            Home Nature Unicon N V      ABW_1
# 12        Aruba          ABW                                        ABW_2
# 13        Aruba          ABW              Maspralto Enterprise     11_ABW
# 14        Aruba          ABW           Bon Bini Cargo Services    257_COL
# 15        Aruba          ABW                         Boardwalk     13_ABW
# 16        Aruba          ABW          Ultimate Automobiles N V      8_ABW
# 17        Aruba          ABW                                        ABW_3
# 18        Aruba          ABW                          Banjolux     15_ABW
# 19        Aruba          ABW          Landglass Distibutor Ind      5_ABW
#
#     matching_score  new                          old_name
# 0              0.0    0           Home & Nature Unicon Nv
# 1              0.0    0                Gca Auto Sales N V
# 2              0.0    0       Tricen Maintenance Services
# 3            100.0    0                Gca Auto Sales N V
# 4              0.0    0                   Osyth Henriquez
# 5              0.0    0          Landglass Distibutor Ind
# 6              0.0    0         Simple Beauty Trading N V
# 7            100.0    0           Home & Nature Unicon Nv
# 8              0.0    0  Re Yrausquin And Sons (Aruba) Nv
# 9              0.0    0          Ultimate Automobiles N V
# 10             0.0    0             W G Den Heijer Zn B V
# 11            89.0    1
# 12             0.0    1
# 13             0.0    0              Maspralto Enterprise
# 14             0.0    0           Bon Bini Cargo Services
# 15             0.0    0                         Boardwalk
# 16           100.0    0          Ultimate Automobiles N V
# 17             0.0    1
# 18             0.0    0                          Banjolux
# 19           100.0    0          Landglass Distibutor Ind

# %%
import os
import pandas as pd
from fuzzywuzzy import fuzz
from tqdm import tqdm
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from sklearn.metrics import accuracy_score
from IPython.display import display

# Now, divide the data into training and test sets

# Load the cleaned dataset
cleaned_df = pd.read_csv('Cleaned_ForeignNames_2019_2021.csv')

# Drop rows with NaN values in 'foreign' and 'cleaned_name'
cleaned_df = cleaned_df.dropna(subset=['foreign', 'cleaned_name'])

# Define features and labels
X = cleaned_df['foreign']  # Original names
y = cleaned_df['cleaned_name']  # Cleaned names

# Split the data into training (70%) and testing (30%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Develop and train a machine learning model
model = make_pipeline(TfidfVectorizer(), MultinomialNB())
model.fit(X_train, y_train)

# Predict on the test set
y_pred = model.predict(X_test)

# Evaluate the model
accuracy = accuracy_score(y_test, y_pred)
print(f"Model Accuracy: {accuracy:.2f}")

# Apply the model to the entire dataset to predict cleaned names
cleaned_df['cleaned_name_pred'] = model.predict(cleaned_df['foreign'])

# Save the output file with all observations and fields
cleaned_df.to_csv('outputfile_Jairo_2.csv', index=False)

# Display samples of the output
display(cleaned_df.head())
display(changed_names.head())
